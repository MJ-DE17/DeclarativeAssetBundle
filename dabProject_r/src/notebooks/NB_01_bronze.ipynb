# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

# Read raw CSV
df = spark.read.option("header", True).csv(
    "/Volumes/dev_catalog/sales_schema/sales_volume/sales.csv"
)

# Save as bronze table
df.write.mode("overwrite").saveAsTable("dev_catalog.sales_schema.bronze_sales")

# %%
# %sql

SELECT * FROM dev_catalog.sales_schema.gold_sales;
